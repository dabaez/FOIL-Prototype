# %%
# !mkdir build
# %cd build
# !cmake ../
# !make
# Out:
# mkdir: build: File exists
# /Users/bernardo/research/invint/build
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /Users/bernardo/research/invint/build
# [  1%] Performing update step for 'antlr4_runtime'
# From https://github.com/antlr/antlr4
#    e404d26f6..3601dcad5  master     -> origin/master
# Ignoring path runtime/Cpp/runtime/thirdparty/utfcpp/
# Successfully rebased and updated refs/heads/master.
# Already up to date!
# [  3%] Performing configure step for 'antlr4_runtime'
# loading initial cache file /Users/bernardo/research/invint/build/antlr4_runtime/tmp/antlr4_runtime-cache-.cmake
# CMake Warning at CMakeLists.txt:7 (message):
#   Build type not set, falling back to Release mode.
#
#    To specify build type use:
#    -DCMAKE_BUILD_TYPE=<mode> where <mode> is Debug or Release.
#
#
# -- Building without demo. To enable demo build use: -DWITH_DEMO=True
# CMake Deprecation Warning at CMakeLists.txt:31 (CMAKE_POLICY):
#   The OLD behavior for policy CMP0054 will be removed from a future version
#   of CMake.
#
#   The cmake-policies(7) manual explains that the OLD behaviors of all
#   policies are deprecated and that a policy should be set to OLD only under
#   specific short-term circumstances.  Projects should be ported to the NEW
#   behavior and not rely on setting a policy to OLD.
#
#
# CMake Deprecation Warning at CMakeLists.txt:32 (CMAKE_POLICY):
#   The OLD behavior for policy CMP0045 will be removed from a future version
#   of CMake.
#
#   The cmake-policies(7) manual explains that the OLD behaviors of all
#   policies are deprecated and that a policy should be set to OLD only under
#   specific short-term circumstances.  Projects should be ported to the NEW
#   behavior and not rely on setting a policy to OLD.
#
#
# CMake Deprecation Warning at CMakeLists.txt:33 (CMAKE_POLICY):
#   The OLD behavior for policy CMP0042 will be removed from a future version
#   of CMake.
#
#   The cmake-policies(7) manual explains that the OLD behaviors of all
#   policies are deprecated and that a policy should be set to OLD only under
#   specific short-term circumstances.  Projects should be ported to the NEW
#   behavior and not rely on setting a policy to OLD.
#
#
# CMake Deprecation Warning at CMakeLists.txt:38 (CMAKE_POLICY):
#   The OLD behavior for policy CMP0059 will be removed from a future version
#   of CMake.
#
#   The cmake-policies(7) manual explains that the OLD behaviors of all
#   policies are deprecated and that a policy should be set to OLD only under
#   specific short-term circumstances.  Projects should be ported to the NEW
#   behavior and not rely on setting a policy to OLD.
#
#
# CMake Deprecation Warning at CMakeLists.txt:39 (CMAKE_POLICY):
#   The OLD behavior for policy CMP0054 will be removed from a future version
#   of CMake.
#
#   The cmake-policies(7) manual explains that the OLD behaviors of all
#   policies are deprecated and that a policy should be set to OLD only under
#   specific short-term circumstances.  Projects should be ported to the NEW
#   behavior and not rely on setting a policy to OLD.
#
#
# -- Output libraries to /Users/bernardo/research/invint/build/antlr4_runtime/src/antlr4_runtime/runtime/Cpp/dist
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /Users/bernardo/research/invint/build/antlr4_runtime/src/antlr4_runtime/runtime/Cpp
# [  5%] No build step for 'antlr4_runtime'
# [  6%] No install step for 'antlr4_runtime'
# [  8%] Completed 'antlr4_runtime'
# [ 13%] Built target antlr4_runtime
# [ 15%] Built target antlr4_runtime-build_static
# [ 18%] Built target fpow
# Scanning dependencies of target gVisitor
# [ 20%] Building CXX object CMakeFiles/gVisitor.dir/src/greedyVisitor.cpp.o
# /Users/bernardo/research/invint/src/greedyVisitor.cpp:65:1: warning: non-void
#       function does not return a value in all control paths [-Wreturn-type]
# }
# ^
# /Users/bernardo/research/invint/src/greedyVisitor.cpp:82:1: warning: non-void
#       function does not return a value in all control paths [-Wreturn-type]
# }
# ^
# /Users/bernardo/research/invint/src/greedyVisitor.cpp:125:1: warning: non-void
#       function does not return a value in all control paths [-Wreturn-type]
# }
# ^
# 3 warnings generated.
# [ 22%] Linking CXX static library libgVisitor.a
# [ 28%] Built target gVisitor
# Scanning dependencies of target dtnode
# [ 30%] Building CXX object src/CMakeFiles/dtnode.dir/DTNode.cpp.o
# [ 32%] Linking CXX static library libdtnode.a
# [ 32%] Built target dtnode
# Scanning dependencies of target paperalgo
# [ 33%] Building CXX object CMakeFiles/paperalgo.dir/src/paperalgo.cpp.o
# [ 35%] Building CXX object CMakeFiles/paperalgo.dir/antlr4cpp_generated_src/invLexer/invLexer.cpp.o
# [ 37%] Building CXX object CMakeFiles/paperalgo.dir/antlr4cpp_generated_src/invParser/invParser.cpp.o
# [ 38%] Linking CXX static library libpaperalgo.a
# [ 42%] Built target paperalgo
# Scanning dependencies of target qChecker2
# [ 44%] Building CXX object CMakeFiles/qChecker2.dir/src/queryChecker2.cpp.o
# /Users/bernardo/research/invint/src/queryChecker2.cpp:88:1: warning: non-void
#       function does not return a value in all control paths [-Wreturn-type]
# }
# ^
# 1 warning generated.
# [ 45%] Building CXX object CMakeFiles/qChecker2.dir/antlr4cpp_generated_src/invLexer/invLexer.cpp.o
# [ 47%] Building CXX object CMakeFiles/qChecker2.dir/antlr4cpp_generated_src/invParser/invParser.cpp.o
# [ 49%] Linking CXX static library libqChecker2.a
# [ 52%] Built target qChecker2
# Scanning dependencies of target perceptron
# [ 54%] Building CXX object src/CMakeFiles/perceptron.dir/perceptron.cpp.o
# [ 55%] Linking CXX static library libperceptron.a
# [ 55%] Built target perceptron
# [ 59%] Built target errorListener
# Scanning dependencies of target dt
# [ 61%] Building CXX object src/CMakeFiles/dt.dir/DecisionTree.cpp.o
# [ 62%] Linking CXX static library libdt.a
# [ 62%] Built target dt
# Scanning dependencies of target main2
# [ 64%] Building CXX object CMakeFiles/main2.dir/src/main2.cpp.o
# [ 66%] Building CXX object CMakeFiles/main2.dir/antlr4cpp_generated_src/invLexer/invLexer.cpp.o
# [ 67%] Building CXX object CMakeFiles/main2.dir/antlr4cpp_generated_src/invParser/invParser.cpp.o
# [ 69%] Linking CXX executable main2
# [ 72%] Built target main2
# Scanning dependencies of target qChecker
# [ 74%] Building CXX object CMakeFiles/qChecker.dir/src/queryChecker.cpp.o
# /Users/bernardo/research/invint/src/queryChecker.cpp:71:1: warning: non-void
#       function does not return a value in all control paths [-Wreturn-type]
# }
# ^
# 1 warning generated.
# [ 76%] Linking CXX static library libqChecker.a
# [ 83%] Built target qChecker
# Scanning dependencies of target main
# [ 84%] Building CXX object CMakeFiles/main.dir/src/main.cpp.o
# [ 86%] Linking CXX executable main
# [ 93%] Built target main
# Scanning dependencies of target dttest
# [ 94%] Building CXX object CMakeFiles/dttest.dir/src/DTtest.cpp.o
# [ 96%] Linking CXX executable dttest
# [ 96%] Built target dttest
# Scanning dependencies of target test_generator
# [ 98%] Building CXX object src/CMakeFiles/test_generator.dir/generator.cpp.o
# [100%] Linking CXX executable test_generator
# [100%] Built target test_generator

# %%
import time
import subprocess
import numpy as np
import json
import pandas as pd

# %%
def time1(query):
    q = open("query.txt","w")
    q.write(query + "\n")
    q.close()
    times = []
    out = ""
    for i in range(5):
        d1 = time.process_time()
        try:
            sp = subprocess.run("./main2 --model=dt --file=dt.txt < query.txt", shell = True, capture_output = True, timeout = 10)
            out = sp.stdout.splitlines()[2]
        except:
            print("timeout with query " + query)
            times = [10,10,10,10,10]
            out = "timeout"
            break
        #timeout!!!
        d2 = time.process_time()
        times.append(d2-d1)
    return (times , out)

def random_constant(query , dt_size):
    ans = ""
    idx = 1
    for i in range(len(query[0])):
        if (query[0][i] == 'C'):
            ans+="[ "
            for j in range(dt_size):
                if (j):
                    ans += " , "
                val = query[idx][j]
                if (val == 2): val = '?'
                else: val = str(val)
                ans += val
            ans += " ] "
            idx+=1
        else:
            ans+=query[0][i]
    return ans

def generate_query(squeries , nvars , rng):
    query = ""
    isnot = rng.integers(2)
    if (isnot):
        query += " ~ ( "
    if (squeries == 1):
        
        if (nvars == 1):
            opt = rng.integers(3)
        else:
            opt = rng.integers(4)
        
        if (opt == 0):
            
            query += " P ( x" + str( rng.integers(nvars) + 1 ) + " ) "
        
        if (opt == 1):
            
            query += " C <= x" + str( rng.integers(nvars) + 1 ) + " "
        
        if (opt == 2):
            
            query += " x" + str( rng.integers(nvars) + 1 ) + " <= C "
            
        if (opt == 3):
            
            x1 = rng.integers(nvars) + 1
            x2 = rng.integers(nvars) + 1
            while (x2 == x1):
                x2 = rng.integers(nvars) + 1
            query += " x" + str(x1) + " <= x" + str(x2) + " "
        
    else:
        
        query += " ( "
        fs = rng.integers(squeries-1) + 1
        query += generate_query(fs , nvars , rng)
        
        if ( rng.integers(2) ):
            query += " ) V ( "
        else:
            query += " ) ^ ( "
            
        query += generate_query(squeries - fs , nvars , rng) + " ) "
    
    if (isnot):
        query += " ) "
    
    return query

def time_queries(dt_name , queries, rng):
    
    data = {}
    
    with open("../dtrees/" + dt_name) as json_file:
        data = json.load(json_file)
        
    with open('dt.txt', 'w') as outfile:
        json.dump(data, outfile)
    
    times = []
    timesr = []
    
    for q in queries:
        queryt = random_constant(q , len( data["feature_names"] ) )
        ctimes = time1( queryt )
        timep = ( sum(ctimes[0]) - max(ctimes[0]) - min(ctimes[0]))/3
        timesr.append( timep )
        finalarr = [queryt] + ctimes[0] + [ctimes[1]] + [timep]
        times.append(finalarr)
        
    df = pd.DataFrame( times , columns = ["query" , "t1" , "t2" , "t3" , "t4" , "t5" , "ans" , "tp"] )
    
    df.to_csv(dt_name + ".csv")
    
    return timesr

def test_trees(qsize, nvars , nqueries, seed):
    data = []
    rng = np.random.default_rng(seed)
    queries = []
    dims = [3, 5, 10, 15, 20, 25, 30]
    leaves =  [5, 10, 15, 20, 50, 100, 150, 200, 500, 1000, 2000]
    for i in range(nqueries):
        q = ""
        ex = rng.integers(2)
        for j in range(nvars):
            if (ex):
                q += "Exists x" + str(j + 1) + ", "
            else:
                q += "Forall x" + str(j + 1) + ", "
        q += generate_query(qsize , nvars , rng)
        nconstants = q.count('C')
        fquery = [q]
        for i in range(nconstants):
            c = []
            for j in range( max(dims) ):
                c.append( rng.integers(3) )
            fquery.append(c)
        queries.append(fquery)
    infop = [ ]
    for l in leaves:
        for d in dims:
            infop.append( [d , l ] +  time_queries( "dim_" + str(d) + "_nleaves_" + str(l) + ".json" , queries , rng) )
            print( str(l) + " " + str(d) + " " + str(sum(infop[len(infop)-1][2:])/nqueries) )
    
    qs = []
    for i in range(nqueries):
        qs.append( queries[i][0] )
    df = pd.DataFrame( infop , columns = ["dimension" , "leaves" ] + qs )
    df.to_csv("final_data.csv")

# %%
test_trees(10,3,10,5)
# Out:
# 5 3 0.0010879333333333613
# 5 5 0.001099400000000017
# 5 10 0.001166133333333323
